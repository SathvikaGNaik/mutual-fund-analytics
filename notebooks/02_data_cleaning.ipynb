# %% [markdown]
# # Data Cleaning
#
# This notebook performs preprocessing before loading data into the SQLite database.

# %%
import pandas as pd
from pathlib import Path

# %%
nav = pd.read_csv("../data/raw/02_nav_history.csv")

# %%
nav["date"] = pd.to_datetime(nav["date"])

# %%
nav.drop_duplicates(inplace=True)

# %%
nav.isna().sum()
# Out:
# amfi_code    0
# date         0
# nav          0
# dtype: int64

# %%
nav.to_csv("../data/processed/clean_nav_history.csv", index=False)

# %% [markdown]
# The cleaned datasets were exported to the processed folder and later used by the ETL pipeline and Power BI dashboard.
